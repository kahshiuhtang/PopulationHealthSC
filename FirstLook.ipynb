# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
address = "HospitalDischarges.csv"
file = pd.read_csv(address, index_col=[0])
file.head()
# Out:
#                     Hospital County  Operating Certificate Number  \
# Health Service Area
# Long Island                 Suffolk                       5151001
# Long Island                 Suffolk                       5151001
# Long Island                 Suffolk                       5151001
# Long Island                 Suffolk                       5151001
# Long Island                 Suffolk                       5151001
#
#                      Facility ID        Facility Name Age Group  \
# Health Service Area
# Long Island                  245  University Hospital  18 to 29
# Long Island                  245  University Hospital  50 to 69
# Long Island                  245  University Hospital  50 to 69
# Long Island                  245  University Hospital  30 to 49
# Long Island                  245  University Hospital  30 to 49
#
#                     Zip Code - 3 digits Gender                    Race  \
# Health Service Area
# ...

# %%
#file['Total Charges'] = file['Total Charges'].str.replace(',', '', regex=True)
#file['Total Charges'] = file['Total Charges'].astype(float)
#file['Total Costs'] = file['Total Costs'].str.replace(',', '', regex=True)
#file['Total Costs'] = file['Total Costs'].astype(float)
file['Payment Typology 1'] = file['Payment Typology 1'].str.replace(',', '', regex=True)
file['Payment Typology 1'] = file['Payment Typology 1'].astype("string")
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5519 entries, Long Island to Long Island
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Hospital County                      5519 non-null   object
#  1   Operating Certificate Number         5519 non-null   int64
#  2   Facility ID                          5519 non-null   int64
#  3   Facility Name                        5519 non-null   object
#  4   Age Group                            5519 non-null   object
#  5   Zip Code - 3 digits                  5456 non-null   object
#  6   Gender                               5519 non-null   object
#  7   Race                                 5519 non-null   object
#  8   Ethnicity                            5519 non-null   object
#  9   Length of Stay                       5519 non-null   int64
#  10  Type of Admission                    5519 non-null   object
# ...

# %%
x1 = file.loc[(file['Facility Name'] == "University Hospital")]['Total Charges']
y1 = file.loc[(file['Facility Name'] == "University Hospital")]['Total Costs']

x2 = file.loc[(file['Facility Name'] == "Brookhaven Memorial Hospital Medical Center Inc")]['Total Charges']
y2 = file.loc[(file['Facility Name'] == "Brookhaven Memorial Hospital Medical Center Inc")]['Total Costs']

x3 = file.loc[(file['Facility Name'] == "Eastern Long Island Hospital")]['Total Charges']
y3 = file.loc[(file['Facility Name'] == "Eastern Long Island Hospital")]['Total Costs']

x4 = file.loc[(file['Facility Name'] == "John T Mather Memorial Hospital of Port Jefferson New York Inc")]['Total Charges']
y4 = file.loc[(file['Facility Name'] == "John T Mather Memorial Hospital of Port Jefferson New York Inc")]['Total Costs']

x5 = file.loc[(file['Facility Name'] == "Southside Hospital")]['Total Charges']
y5 = file.loc[(file['Facility Name'] == "Southside Hospital")]['Total Costs']

x6 = file.loc[(file['Facility Name'] == "St Catherine of Siena Hospital")]['Total Charges']
y6 = file.loc[(file['Facility Name'] == "St Catherine of Siena Hospital")]['Total Costs']

# %%
print(x1.mean())
print(y1.mean())
plt.show()
# Out:
# 67469.4602952503
# 22937.407522464724

# %%
x1 = file.loc[(file['Facility Name'] == "University Hospital")]['Length of Stay']
y1 = file.loc[(file['Facility Name'] == "University Hospital")]['Total Costs']

x2 = file.loc[(file['Facility Name'] == "Brookhaven Memorial Hospital Medical Center Inc")]['Total Charges']
y2 = file.loc[(file['Facility Name'] == "Brookhaven Memorial Hospital Medical Center Inc")]['Total Costs']

x3 = file.loc[(file['Facility Name'] == "Eastern Long Island Hospital")]['Total Charges']
y3 = file.loc[(file['Facility Name'] == "Eastern Long Island Hospital")]['Total Costs']

x4 = file.loc[(file['Facility Name'] == "John T Mather Memorial Hospital of Port Jefferson New York Inc")]['Total Charges']
y4 = file.loc[(file['Facility Name'] == "John T Mather Memorial Hospital of Port Jefferson New York Inc")]['Total Costs']

x5 = file.loc[(file['Facility Name'] == "Southside Hospital")]['Total Charges']
y5 = file.loc[(file['Facility Name'] == "Southside Hospital")]['Total Costs']

x6 = file.loc[(file['Facility Name'] == "St Catherine of Siena Hospital")]['Total Charges']
y6 = file.loc[(file['Facility Name'] == "St Catherine of Siena Hospital")]['Total Costs']
